# %%
import pandas, keras, numpy, matplotlib.pyplot
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
ds = pandas.read_csv("hotel_bookings.csv")
ds.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
dse = ds.dropna()
X = dse.drop(columns=['is_canceled','reservation_status','reservation_status_date'])
X['hotel']=X['hotel'].astype('category')
X['hotel']= X['hotel'].cat.codes
X['arrival_date_month']=X['arrival_date_month'].astype('category')
X['arrival_date_month']= X['arrival_date_month'].cat.codes
X['meal']=X['meal'].astype('category')
X['meal']= X['meal'].cat.codes
X['country']=X['country'].astype('category')
X['country']= X['country'].cat.codes
X['market_segment']=X['market_segment'].astype('category')
X['market_segment']= X['market_segment'].cat.codes
X['distribution_channel']=X['distribution_channel'].astype('category')
X['distribution_channel']= X['distribution_channel'].cat.codes
X['reserved_room_type']=X['reserved_room_type'].astype('category')
X['reserved_room_type']= X['reserved_room_type'].cat.codes
X['assigned_room_type']=X['assigned_room_type'].astype('category')
X['assigned_room_type']= X['assigned_room_type'].cat.codes
X['deposit_type']=X['deposit_type'].astype('category')
X['deposit_type']= X['deposit_type'].cat.codes
X['agent']=X['agent'].astype('category')
X['agent']= X['agent'].cat.codes
X['customer_type']=X['customer_type'].astype('category')
X['customer_type']= X['customer_type'].cat.codes


y = dse['is_canceled']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[40  0]
#  [ 4  0]]
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95        40
#            1       0.00      0.00      0.00         4
#
#     accuracy                           0.91        44
#    macro avg       0.45      0.50      0.48        44
# weighted avg       0.83      0.91      0.87        44
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
model = LogisticRegression(solver='liblinear', random_state=0)
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
model.predict_proba(X)
print(model.score(X, y))
print(confusion_matrix(y, model.predict(X)))
print(classification_report(y, model.predict(X)))
# Out:
# [2.49326106e-05]
# [[ 0.26001708  0.0085805  -0.00473344 -0.21224335  0.04257505  0.04820125
#   -0.22140012 -0.45158506 -0.30461824 -0.02839138  0.          0.20164235
#    0.59429727 -0.72708549 -0.35118001 -0.12101665 -0.0012693   0.04831132
#    0.41557613 -0.82087293  0.15873438 -0.04694639 -0.05284484 -0.0038877
#    0.          1.2207768   0.02103568 -0.09776776 -0.92250683]]
# 0.9400921658986175
# [[197   3]
#  [ 10   7]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       200
#            1       0.70      0.41      0.52        17
#
#     accuracy                           0.94       217
#    macro avg       0.83      0.70      0.74       217
# weighted avg       0.93      0.94      0.93       217

# %%
df = ds.drop(['arrival_date_year','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights','stays_in_week_nights','children','babies','company','adr'], axis=1)
df.corr(method='pearson', min_periods=1)
# Out:
#                                 is_canceled  lead_time    adults  \
# is_canceled                        1.000000   0.293123  0.060017
# lead_time                          0.293123   1.000000  0.119519
# adults                             0.060017   0.119519  1.000000
# is_repeated_guest                 -0.084793  -0.124410 -0.146426
# previous_cancellations             0.110133   0.086042 -0.006738
# previous_bookings_not_canceled    -0.057358  -0.073548 -0.107983
# booking_changes                   -0.144381   0.000149 -0.051673
# agent                             -0.083114  -0.069741 -0.035594
# days_in_waiting_list               0.054186   0.170084 -0.008283
# required_car_parking_spaces       -0.195498  -0.116451  0.014785
# total_of_special_requests         -0.234658  -0.095712  0.122884
#
#                                 is_repeated_guest  previous_cancellations  \
# is_canceled                             -0.084793                0.110133
# ...

# %%
df2 = ds.drop(['arrival_date_year','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights','stays_in_week_nights','children','babies','company','adr','arrival_date_month','meal','reserved_room_type','reservation_status','reservation_status_date'], axis=1)
df2.apply(lambda x : pandas.factorize(x)[0]).corr(method='pearson', min_periods=1)
# Out:
#                                    hotel  is_canceled  lead_time    adults  \
# hotel                           1.000000     0.136531   0.058665  0.066951
# is_canceled                     0.136531     1.000000   0.241626 -0.055894
# lead_time                       0.058665     0.241626   1.000000 -0.090795
# adults                          0.066951    -0.055894  -0.090795  1.000000
# country                         0.142415    -0.097097  -0.061008  0.026822
# market_segment                  0.108410     0.238335   0.337568 -0.060598
# distribution_channel            0.183816     0.169727   0.179870 -0.058521
# is_repeated_guest              -0.050421    -0.084793  -0.111374  0.101150
# previous_cancellations          0.034459     0.140984   0.082902 -0.010734
# previous_bookings_not_canceled -0.004164    -0.057426  -0.060355  0.063451
# assigned_room_type             -0.146113    -0.125211  -0.102660  0.182619
# ...

# %%
dse = ds.dropna()
X = dse.drop(columns=['is_canceled','arrival_date_year','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights','stays_in_week_nights','children','babies','company','adr','arrival_date_month','meal','reserved_room_type','reservation_status','reservation_status_date'])
X['hotel']=X['hotel'].astype('category')
X['hotel']= X['hotel'].cat.codes

X['country']=X['country'].astype('category')
X['country']= X['country'].cat.codes
X['market_segment']=X['market_segment'].astype('category')
X['market_segment']= X['market_segment'].cat.codes
X['distribution_channel']=X['distribution_channel'].astype('category')
X['distribution_channel']= X['distribution_channel'].cat.codes

X['assigned_room_type']=X['assigned_room_type'].astype('category')
X['assigned_room_type']= X['assigned_room_type'].cat.codes
X['deposit_type']=X['deposit_type'].astype('category')
X['deposit_type']= X['deposit_type'].cat.codes
X['agent']=X['agent'].astype('category')
X['agent']= X['agent'].cat.codes
X['customer_type']=X['customer_type'].astype('category')
X['customer_type']= X['customer_type'].cat.codes


y = dse['is_canceled']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

classifier = KNeighborsClassifier(n_neighbors=5)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[38  2]
#  [ 3  1]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        40
#            1       0.33      0.25      0.29         4
#
#     accuracy                           0.89        44
#    macro avg       0.63      0.60      0.61        44
# weighted avg       0.87      0.89      0.88        44

# %%
model = LogisticRegression(solver='liblinear', random_state=0)
model.fit(X, y)
print(model.intercept_)
print(model.coef_)
model.predict_proba(X)
print(model.score(X, y))
print(confusion_matrix(y, model.predict(X)))
print(classification_report(y, model.predict(X)))
# Out:
# [-0.81986932]
# [[-3.20639138e-01  7.82096340e-04 -5.45219526e-01  3.03002385e-01
#   -7.30963840e-01  4.70844572e-02 -1.18076810e-01 -2.99368586e-03
#   -2.28726094e-01 -2.83228170e-01 -1.27930150e-01 -9.91557689e-02
#   -1.13375647e-01  0.00000000e+00 -3.02071727e-01 -2.88875197e-01
#   -7.98091467e-01]]
# 0.9032258064516129
# [[196   4]
#  [ 17   0]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       200
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.90       217
#    macro avg       0.46      0.49      0.47       217
# weighted avg       0.85      0.90      0.87       217
